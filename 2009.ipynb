# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_to_load = (r'C:\Users\watso\Documents\Data_Science_Bootcamp\csb_project\csb\2009.csv')


csb_2009_data = pd.read_csv(file_to_load)
csb_2009_df = pd.DataFrame(csb_2009_data)
display(csb_2009_df.head())
# Out:
#   CALLERTYPE DATECANCELLED           DATEINVTDONE           DATETIMECLOSED  \
# 0        NaN           NaN  2009-01-05 00:00:00.0   2014-12-03 11:16:34.96
# 1        NaN           NaN  2009-01-12 00:00:00.0  2014-12-03 11:20:57.813
# 2        NaN           NaN  2009-01-07 00:00:00.0    2009-01-12 10:20:07.0
# 3        NaN           NaN  2009-01-06 00:00:00.0  2019-05-02 07:58:26.083
# 4        NaN           NaN  2009-01-07 00:00:00.0    2009-01-09 15:09:25.0
#
#             DATETIMEINIT                      DESCRIPTION  \
# 0  2009-01-02 08:26:34.0  Requires caller name and number
# 1  2009-01-02 16:50:13.0             Unsanitary Pets, Ext
# 2  2009-01-05 11:04:04.0        Illegal Use, Open Storage
# 3  2009-01-05 11:07:07.0                             Bats
# 4  2009-01-06 09:35:25.0             Cntnr overflow/bulky
#
#                                          EXPLANATION      EXPR1  \
# 0                                                NaN        NaN
# ...

# %%
csb_2009_df.iloc[:,:].fillna(0)
# Out:
#     CALLERTYPE DATECANCELLED           DATEINVTDONE           DATETIMECLOSED  \
# 0            0             0  2009-01-05 00:00:00.0   2014-12-03 11:16:34.96
# 1            0             0  2009-01-12 00:00:00.0  2014-12-03 11:20:57.813
# 2            0             0  2009-01-07 00:00:00.0    2009-01-12 10:20:07.0
# 3            0             0  2009-01-06 00:00:00.0  2019-05-02 07:58:26.083
# 4            0             0  2009-01-07 00:00:00.0    2009-01-09 15:09:25.0
# ..         ...           ...                    ...                      ...
# 696          0             0  2009-12-22 00:00:00.0    2009-12-28 15:18:35.0
# 697        WEB             0  2010-01-04 00:00:00.0    2010-01-04 10:39:01.0
# 698          0             0  2010-01-04 00:00:00.0    2010-01-04 15:44:12.0
# 699          0             0  2010-01-25 00:00:00.0    2010-01-25 08:37:39.0
# 700          0             0  2010-02-02 00:00:00.0    2013-05-06 09:14:26.0
#
# ...

# %%
csb_2009_df.columns
# Out:
# Index(['CALLERTYPE', 'DATECANCELLED', 'DATEINVTDONE', 'DATETIMECLOSED',
#        'DATETIMEINIT', 'DESCRIPTION', 'EXPLANATION', 'EXPR1', 'GROUP',
#        'NEIGHBORHOOD', 'PLAIN_ENGLISH_NAME_FOR_PROBLEMCODE', 'PRJCOMPLETEDATE',
#        'PROBADDRESS', 'PROBADDTYPE', 'PROBLEMCODE', 'PROBZIP', 'REQUESTID',
#        'SRX', 'SRY', 'STATUS', 'SUBMITTO', 'WARD'],
#       dtype='object')

# %%
csb_2009_df['WARD']=pd.to_numeric(csb_2009_df['WARD'], errors='coerce')

# %%
c2009df=csb_2009_df[['CALLERTYPE', 'DATETIMEINIT', 'DESCRIPTION', 'EXPLANATION','NEIGHBORHOOD', 'PLAIN_ENGLISH_NAME_FOR_PROBLEMCODE', 'PRJCOMPLETEDATE',
       'PROBADDRESS', 'PROBADDTYPE', 'PROBZIP', 'STATUS', 'SUBMITTO', 'WARD']]
c2009df
# Out:
#     CALLERTYPE           DATETIMEINIT                      DESCRIPTION  \
# 0          NaN  2009-01-02 08:26:34.0  Requires caller name and number
# 1          NaN  2009-01-02 16:50:13.0             Unsanitary Pets, Ext
# 2          NaN  2009-01-05 11:04:04.0        Illegal Use, Open Storage
# 3          NaN  2009-01-05 11:07:07.0                             Bats
# 4          NaN  2009-01-06 09:35:25.0             Cntnr overflow/bulky
# ..         ...                    ...                              ...
# 696        NaN  2009-12-22 12:42:03.0             Cntnr overflow/bulky
# 697        WEB  2009-12-24 09:44:20.0        Illegal Use, Open Storage
# 698        NaN  2009-12-29 11:13:43.0        Illegal Use, Open Storage
# 699        NaN  2009-12-29 13:07:38.0                Inspect City Tree
# 700        NaN  2009-12-31 15:10:29.0             Inspect Private Tree
#
#                                            EXPLANATION  NEIGHBORHOOD  \
# ...

# %%
warddf=c2009df[c2009df.WARD==9.0]
warddf
# Out:
#     CALLERTYPE           DATETIMEINIT                           DESCRIPTION  \
# 3          NaN  2009-01-05 11:07:07.0                                  Bats
# 7          NaN  2009-01-08 08:10:12.0  Property Maintenance Code - Exterior
# 43         NaN  2009-02-12 11:06:24.0   Derelict Vehicle - Private Property
# 74         NaN  2009-03-06 12:18:35.0   Derelict Vehicle - Private Property
# 92         NaN  2009-03-24 10:23:57.0  Property Maintenance Code - Exterior
# 107        NaN  2009-04-07 08:54:59.0   Derelict Vehicle - Private Property
# 116        NaN  2009-04-15 15:07:23.0       Derelict Vehicle - Right of Way
# 135        NaN  2009-04-29 09:21:36.0            Vacant Building, Unsecured
# 166        NaN  2009-05-12 16:07:53.0  Property Maintenance Code - Exterior
# 179        NaN  2009-05-21 09:03:52.0                   Weeds-Occupied Ppty
# 228        NaN  2009-06-12 16:26:46.0                    Missed Cut - V Lot
# ...

# %%
grpwarddf=warddf.groupby('SUBMITTO').count()
grpwarddf.sort_values('NEIGHBORHOOD', ascending=False)
# Out:
#                   CALLERTYPE  DATETIMEINIT  DESCRIPTION  EXPLANATION  \
# SUBMITTO
# NST,                       1             7            7            0
# BUILDING DIV,              0             6            6            1
# FORESTRY,                  0             5            5            2
# ANIMAL CARE,               0             2            2            0
# COMM SANITATION,           0             1            1            0
# CSB,                       0             1            1            0
#
#                   NEIGHBORHOOD  PLAIN_ENGLISH_NAME_FOR_PROBLEMCODE  \
# SUBMITTO
# NST,                         7                                   6
# BUILDING DIV,                6                                   6
# FORESTRY,                    5                                   5
# ANIMAL CARE,                 2                                   2
# COMM SANITATION,             1                                   1
# ...

# %%
bywarddf=c2009df.groupby(['SUBMITTO', 'WARD']).count()
bywarddf.head(28)
# Out:
#                       CALLERTYPE  DATETIMEINIT  DESCRIPTION  EXPLANATION  \
# SUBMITTO        WARD
# ANIMAL CARE,    3.0            0             1            1            0
#                 8.0            0             1            1            0
#                 9.0            0             2            2            0
#                 11.0           0             1            1            0
#                 12.0           0             1            1            1
#                 17.0           0             1            1            1
#                 18.0           0             1            1            1
#                 20.0           0             1            1            0
#                 22.0           0             1            1            1
#                 24.0           0             2            2            1
#                 25.0           0             1            1            0
# ...

# %%
bydeptdf=c2009df.groupby('SUBMITTO').count()
bydeptdf.sort_values('NEIGHBORHOOD', ascending=False)
# Out:
#                                CALLERTYPE  DATETIMEINIT  DESCRIPTION  \
# SUBMITTO
# FORESTRY,                              59           382          382
# NST,                                    5           122          122
# REFUSE,                                 4            47           47
# BUILDING DIV,                           4            39           39
# TRAFFIC DIVISION, 511                   2            28           28
# ANIMAL CARE,                            0            15           15
# COMM SANITATION,                        1            14           14
# STREET DEPT, 510                        2            11           11
# CSB,                                    2             9            9
# ENVIRONMENTAL INVESTIGATIONS,           0             9            9
# OP BRIGHTSIDE,                          1             5            5
# VECTOR CNTRL,                           1             4            4
# ...
