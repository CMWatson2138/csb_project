# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_to_load = (r'C:\Users\watso\Documents\Data_Science_Bootcamp\csb_project\csb\2020.csv')


csb_2020_data = pd.read_csv(file_to_load, low_memory=False)
csb_2020_df = pd.DataFrame(csb_2020_data)
display(csb_2020_df.head())
# Out:
#   CALLERTYPE DATECANCELLED DATEINVTDONE DATETIMECLOSED DATETIMEINIT  \
# 0        WEB           NaN    1/23/2020      1/23/2020     1/1/2020
# 1      PHONE           NaN     1/1/2020      2/28/2020     1/1/2020
# 2      PHONE           NaN     1/1/2020       1/1/2020     1/1/2020
# 3      PHONE           NaN     1/1/2020       1/1/2020     1/1/2020
# 4      PHONE           NaN     1/1/2020       1/1/2020     1/1/2020
#
#             DESCRIPTION                                        EXPLANATION  \
# 0  Illegl Use-Opn Storg  Any zoning code violations, including derelict...
# 1         Light Damaged                                                NaN
# 2           Signal Dark                                                NaN
# 3  Sign needs attention  Select this option for non-critical signs (str...
# 4  Sign needs attention  Select this option for non-critical signs (str...
#
#   EXPR1                 GROUP NEIGHBORHOOD  ...  \
# 0   NaN   Prpty Insp Exterior           43  ...
# ...

# %%
csb_2020_df.iloc[:,:].fillna(0)
# Out:
#        CALLERTYPE DATECANCELLED DATEINVTDONE DATETIMECLOSED DATETIMEINIT  \
# 0             WEB             0    1/23/2020      1/23/2020     1/1/2020
# 1           PHONE             0     1/1/2020      2/28/2020     1/1/2020
# 2           PHONE             0     1/1/2020       1/1/2020     1/1/2020
# 3           PHONE             0     1/1/2020       1/1/2020     1/1/2020
# 4           PHONE             0     1/1/2020       1/1/2020     1/1/2020
# ...           ...           ...          ...            ...          ...
# 108671          0             0     1/5/2021       1/5/2021   12/31/2020
# 108672      PHONE    12/31/2020            0              0   12/31/2020
# 108673          0    12/31/2020            0              0   12/31/2020
# 108674          0             0     1/7/2021       1/7/2021   12/31/2020
# 108675          0             0     1/4/2021       1/4/2021   12/31/2020
#
#                                  DESCRIPTION  \
# ...

# %%
csb_2020_df.columns
# Out:
# Index(['CALLERTYPE', 'DATECANCELLED', 'DATEINVTDONE', 'DATETIMECLOSED',
#        'DATETIMEINIT', 'DESCRIPTION', 'EXPLANATION', 'EXPR1', 'GROUP',
#        'NEIGHBORHOOD', 'PLAIN_ENGLISH_NAME_FOR_PROBLEMCODE', 'PRJCOMPLETEDATE',
#        'PROBADDRESS', 'PROBADDTYPE', 'PROBLEMCODE', 'PROBZIP', 'REQUESTID',
#        'SRX', 'SRY', 'STATUS', 'SUBMITTO', 'WARD'],
#       dtype='object')

# %%
csb_2020_df['WARD']=pd.to_numeric(csb_2020_df['WARD'], errors='coerce')

# %%
c19df=csb_2020_df[['CALLERTYPE', 'DATETIMEINIT', 'DESCRIPTION', 'EXPLANATION','NEIGHBORHOOD', 'PLAIN_ENGLISH_NAME_FOR_PROBLEMCODE', 'PRJCOMPLETEDATE',
       'PROBADDRESS', 'PROBADDTYPE', 'PROBZIP', 'STATUS', 'SUBMITTO', 'WARD']]
c19df
# Out:
#        CALLERTYPE DATETIMEINIT                           DESCRIPTION  \
# 0             WEB     1/1/2020                  Illegl Use-Opn Storg
# 1           PHONE     1/1/2020                         Light Damaged
# 2           PHONE     1/1/2020                           Signal Dark
# 3           PHONE     1/1/2020                  Sign needs attention
# 4           PHONE     1/1/2020                  Sign needs attention
# ...           ...          ...                                   ...
# 108671        NaN   12/31/2020         COVID-19 Individual Violation
# 108672      PHONE   12/31/2020                Whole block lights out
# 108673        NaN   12/31/2020                Whole block lights out
# 108674        NaN   12/31/2020  COVID-19 Social Distancing Violation
# 108675        NaN   12/31/2020         COVID-19 Individual Violation
#
#                                               EXPLANATION NEIGHBORHOOD  \
# ...

# %%
warddf=c19df[c19df.WARD==9.0]
warddf
# Out:
#        CALLERTYPE DATETIMEINIT                         DESCRIPTION  \
# 12            WEB     1/1/2020                      Vehicle Towing
# 23            WEB     1/1/2020                      Vehicle Towing
# 157         PHONE     1/2/2020                Rollcart stolen/misg
# 163         PHONE     1/2/2020                  Stray Dog At Large
# 189         PHONE     1/2/2020                  Stray Dog At Large
# ...           ...          ...                                 ...
# 108433        NaN   12/30/2020  Street, alley, or sidewalk cave-in
# 108434      PHONE   12/30/2020                   Inspect City Tree
# 108448        NaN   12/30/2020                      Vehicle Towing
# 108483      PHONE   12/30/2020              Whole block lights out
# 108532      PHONE   12/31/2020                        Cntnr turned
#
#                                               EXPLANATION NEIGHBORHOOD  \
# 12      Report derelict, vandalized, inoperable or aba...           22
# ...

# %%
grpwarddf=warddf.groupby('SUBMITTO').count()
grpwarddf.sort_values('NEIGHBORHOOD', ascending=False)
# Out:
#                                CALLERTYPE  DATETIMEINIT  DESCRIPTION  \
# SUBMITTO
# REFUSE,                               476           813          813
# STREET DEPT, 510                      254           677          677
# STREET DIVISION, 514                  203           544          544
# FORESTRY,                             258           490          490
# TRAFFIC DIVISION, 511                 251           404          404
# BUILDING DIV,                         200           373          373
# ANIMAL CARE,                           97           157          157
# OP BRIGHTSIDE,                         22           124          124
# HEALTH DIR OFC,                        33           115          115
# COMM SANITATION,                       71           114          114
# ENVIRONMENTAL INVESTIGATIONS,          71            97           97
# TREAS PRKG SVC,                        45            61           61
# ...

# %%
bywarddf=c19df.groupby(['SUBMITTO', 'WARD']).count()
bywarddf.head(28)
# Out:
#                      CALLERTYPE  DATETIMEINIT  DESCRIPTION  EXPLANATION  \
# SUBMITTO       WARD
# AIR POLLUTION, 1.0            3             5            5            1
#                2.0            5             7            7            2
#                3.0            4             4            4            2
#                4.0            2             3            3            1
#                6.0            4            18           18            1
#                7.0            3             8            8            2
#                8.0            0             7            7            3
#                9.0            4             5            5            1
#                10.0           1             4            4            0
#                11.0           1             4            4            2
#                12.0           0             1            1            0
#                13.0           2            14           14            2
# ...

# %%
bydeptdf=c19df.groupby('SUBMITTO').count()
bydeptdf.sort_values('NEIGHBORHOOD', ascending=False)
# Out:
#                                CALLERTYPE  DATETIMEINIT  DESCRIPTION  \
# SUBMITTO
# REFUSE,                             17729         24461        24461
# STREET DIVISION, 514                13133         18011        18011
# TRAFFIC DIVISION, 511                9937         13344        13344
# FORESTRY,                            8492         12946        12946
# STREET DEPT, 510                     5707         10040        10040
# BUILDING DIV,                        5915          8416         8416
# HEALTH DIR OFC,                      1142          3417         3417
# ANIMAL CARE,                         2190          2759         2759
# OP BRIGHTSIDE,                       1457          2471         2471
# COMM SANITATION,                     1590          2195         2195
# ENVIRONMENTAL INVESTIGATIONS,        1659          1966         1966
# TREAS PRKG SVC,                      1385          1818         1818
# ...
